# %% [markdown]
# ### 读文件

# %%
with open('text.txt',encoding='utf-8') as f:
    for line in f.readlines():
        file_content=line.strip()

# %%
file_content
# type(file_content)        #str
# Out:
# 'NLTK has been called “a wonderful tool for teaching, and working in, computational linguistics using Python,” and “an amazing library to play with natural language.”'

# %%
with open('Chinese_text.txt',encoding='utf-8') as f:
    for line in f.readlines():
        file_content_ch=line.strip()
file_content_ch
# type(file_content_ch) #str
# Out:
# '宫颈癌和乳腺癌并称女性两大“隐性杀手”。'

# %%
import re
myfile=open('Chinese_text.txt','r',encoding='utf-8')
for line in myfile:
    line=re.sub(r'\n','',line)
    # line=line.strip('\n')
    # line=line.strip('\t')
    print(line)
myfile.close()
# Out:
# 乳腺癌是乳腺上皮细胞在多种致癌因子的作用下，发生增殖失控的现象。疾病早期常表现为乳房肿块、乳头溢液、腋窝淋巴结肿大等症状，晚期可因癌细胞发生远处转移，出现多器官病变，直接威胁患者的生命。
# 乳腺癌常被称为“粉红杀手”，其发病率位居女性恶性肿瘤的首位，男性乳腺癌较为少见。随着医疗水平的提高，乳腺癌已成为疗效最佳的实体肿瘤之一。 [1]
# 宫颈癌和乳腺癌并称女性两大“隐性杀手”。

# %%
help(line.strip)
# Out:
# Help on built-in function strip:
#
# strip(chars=None, /) method of builtins.str instance
#     Return a copy of the string with leading and trailing whitespace removed.
#
#     If chars is given and not None, remove characters in chars instead.

# %%
def _read_file(input_file, quotechar=None):
    with open(input_file, 'r', encoding='utf-8') as f:
        reader = csv.reader(f, delimiter='\t', quotechar=quotechar)
        lines = []
        for line in reader:
            if sys.version_info[0] == 2:
                line = list(unicode(cell, 'utf-8') for cell in line)
            lines.append(line)
        return lines
text_line=  _read_file('Chinese_text.txt')
text_line
# Out:
# [['乳腺癌是乳腺上皮细胞在多种致癌因子的作用下，发生增殖失控的现象。疾病早期常表现为乳房肿块、乳头溢液、腋窝淋巴结肿大等症状，晚期可因癌细胞发生远处转移，出现多器官病变，直接威胁患者的生命。'],
#  ['乳腺癌常被称为“粉红杀手”，其发病率位居女性恶性肿瘤的首位，男性乳腺癌较为少见。随着医疗水平的提高，乳腺癌已成为疗效最佳的实体肿瘤之一。 [1] '],
#  ['宫颈癌和乳腺癌并称女性两大“隐性杀手”。']]

# %%
import csv
import itertools
def _read_file(input_file, quotechar=None):
    with open(input_file, 'r', encoding='utf-8') as f:
        reader = csv.reader(f, delimiter='\t', quotechar=quotechar)
        lines = []
        for line in reader:
            if sys.version_info[0] == 2:
                line = list(unicode(cell, 'utf-8') for cell in line)
            lines.append(line)
        content=''.join(list(itertools.chain(*lines)))
    return content
a=_read_file('Chinese_text.txt')
a
# Out:
# '乳腺癌是乳腺上皮细胞在多种致癌因子的作用下，发生增殖失控的现象。疾病早期常表现为乳房肿块、乳头溢液、腋窝淋巴结肿大等症状，晚期可因癌细胞发生远处转移，出现多器官病变，直接威胁患者的生命。乳腺癌常被称为“粉红杀手”，其发病率位居女性恶性肿瘤的首位，男性乳腺癌较为少见。随着医疗水平的提高，乳腺癌已成为疗效最佳的实体肿瘤之一。 [1] 宫颈癌和乳腺癌并称女性两大“隐性杀手”。'

# %%
import jieba

# text = '我來到北京清華大學'
print('Default (HMM):', '|'.join(jieba.cut(a, cut_all=False, HMM=True)))
# print('All deactivate:', '|'.join(jieba.cut(text, cut_all=False, HMM=False)))
# print('All activate:', '|'.join(jieba.cut(text, cut_all=True, HMM=True)))
# Out:
# Default (HMM): 乳腺癌|是|乳腺|上皮细胞|在|多种|致癌|因子|的|作用|下|，|发生|增殖|失控|的|现象|。|疾病|早期|常|表现|为|乳房|肿块|、|乳头|溢液|、|腋窝|淋巴结|肿大|等|症状|，|晚期|可|因|癌细胞|发生|远处|转移|，|出现|多|器官|病变|，|直接|威胁|患者|的|生命|。|乳腺癌|常|被|称为|“|粉红|杀手|”|，|其|发病率|位居|女性|恶性肿瘤|的|首位|，|男性|乳腺癌|较为|少见|。|随着|医疗|水平|的|提高|，|乳腺癌|已|成为|疗效|最佳|的|实体肿瘤|之一|。| |[|1|]| |宫颈癌|和|乳腺癌|并称|女性|两大|“|隐性|杀手|”|。

# %%
import jieba
b=jieba.lcut(a,cut_all=True)
print(b)
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\zhouy217\AppData\Local\Temp\1\jieba.cache
# Loading model cost 1.158 seconds.
# Prefix dict has been built successfully.
# ['乳腺', '乳腺癌', '腺癌', '是', '乳腺', '上皮', '上皮细胞', '细胞', '在', '多种', '致癌', '因子', '的', '作用', '下', '，', '发生', '增殖', '失控', '的', '现象', '。', '疾病', '早期', '常', '表现', '为', '乳房', '肿块', '、', '乳头', '溢', '液', '、', '腋窝', '淋巴', '淋巴结', '巴结', '肿大', '等', '症状', '，', '晚期', '可因', '癌细胞', '细胞', '发生', '远处', '转移', '，', '出现', '多', '器官', '病变', '，', '直接', '威胁', '患者', '的', '生命', '。', '乳腺', '乳腺癌', '腺癌', '常', '被', '称为', '“', '粉红', '杀手', '”，', '其', '发病', '发病率', '位居', '女性', '性恶', '恶性', '恶性肿瘤', '肿瘤', '的', '首位', '，', '男性', '乳腺', '乳腺癌', '腺癌', '较为', '少见', '。', '随着', '医疗', '水平', '的', '提高', '，', '乳腺', '乳腺癌', '腺癌', '已成', '成为', '疗效', '最佳', '的', '实体', '实体肿瘤', '肿瘤', '之一', '。', ' ', '[', '1', ']', ' ', '', '宫颈', '宫颈癌', '和', '乳腺', '乳腺癌', '腺癌', '并称', '女性', '两', '大', '“', '隐性', '杀手', '”。']

# %%
import jieba
help(jieba.cut)
# Out:
# Help on method cut in module jieba:
#
# cut(sentence, cut_all=False, HMM=True, use_paddle=False) method of jieba.Tokenizer instance
#     The main function that segments an entire sentence that contains
#     Chinese characters into separated words.
#
#     Parameter:
#         - sentence: The str(unicode) to be segmented.
#         - cut_all: Model type. True for full pattern, False for accurate pattern.
#         - HMM: Whether to use the Hidden Markov Model.

# %%
def fenci(datas):
    # cut_words = map(lambda s: list(jieba.cut(s)), datas)
    cut_words=jieba.cut(datas, cut_all=False, HMM=True)
    return list(cut_words)
fenci_list=fenci(a)
print(fenci(a))
# Out:
# ['乳腺癌', '是', '乳腺', '上皮细胞', '在', '多种', '致癌', '因子', '的', '作用', '下', '，', '发生', '增殖', '失控', '的', '现象', '。', '疾病', '早期', '常', '表现', '为', '乳房', '肿块', '、', '乳头', '溢液', '、', '腋窝', '淋巴结', '肿大', '等', '症状', '，', '晚期', '可', '因', '癌细胞', '发生', '远处', '转移', '，', '出现', '多', '器官', '病变', '，', '直接', '威胁', '患者', '的', '生命', '。', '乳腺癌', '常', '被', '称为', '“', '粉红', '杀手', '”', '，', '其', '发病率', '位居', '女性', '恶性肿瘤', '的', '首位', '，', '男性', '乳腺癌', '较为', '少见', '。', '随着', '医疗', '水平', '的', '提高', '，', '乳腺癌', '已', '成为', '疗效', '最佳', '的', '实体肿瘤', '之一', '。', ' ', '[', '1', ']', ' ', '宫颈癌', '和', '乳腺癌', '并称', '女性', '两大', '“', '隐性', '杀手', '”', '。']

# %%
import matplotlib.pyplot as pPlot
from wordcloud import WordCloud, STOPWORDS
import numpy as npy
from PIL import Image

with open('text3.txt',encoding='utf-8') as f:
    for line in f.readlines():
        file_content=line.strip()

dataset =file_content

def create_word_cloud(string):
#    maskArray = npy.array(Image.open("cloud.png"))
   cloud = WordCloud(background_color = "white", max_words = 200, stopwords = set(STOPWORDS))
   cloud.generate(string)
   cloud.to_file("wordCloud.png")
dataset = dataset.lower()
create_word_cloud(dataset)

# %%
import jieba
import matplotlib.pyplot as plt
from wordcloud import WordCloud


# Load
text = a


# Tokenize
text = ' '.join(jieba.cut(text))


# WordCloud
wc = WordCloud(max_words=2000,
               max_font_size=40,
               font_path='./fonts/simhei.ttf',
               background_color='white',
               random_state=42,
               relative_scaling=0)

wc.generate(text)


# Plot
plt.figure()
plt.axis('off')
plt.imshow(wc)
plt.show()

# %%
help(pyecharts.charts)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\1\ipykernel_16608\1024099334.py in <module>
# ----> 1 help(pyecharts.charts)
#
# NameError: name 'pyecharts' is not defined

# %%
import pyecharts.options as opts
from pyecharts.charts import ThemeRiver

x_data = ["DQ", "TY", "SS", "QG", "SY", "DD"]
y_data = [
    ["2015/11/08", 10, "DQ"],
    ["2015/11/09", 15, "DQ"],
    ["2015/11/10", 35, "DQ"],
    ["2015/11/11", 38, "DQ"],
    ["2015/11/12", 22, "DQ"],
    ["2015/11/13", 16, "DQ"],
    ["2015/11/14", 7, "DQ"],
    ["2015/11/15", 2, "DQ"],
    ["2015/11/16", 17, "DQ"],
    ["2015/11/17", 33, "DQ"],
    ["2015/11/18", 40, "DQ"],
    ["2015/11/19", 32, "DQ"],
    ["2015/11/20", 26, "DQ"],
    ["2015/11/21", 35, "DQ"],
    ["2015/11/22", 40, "DQ"],
    ["2015/11/23", 32, "DQ"],
    ["2015/11/24", 26, "DQ"],
    ["2015/11/18", 40, "SY"],
    ["2015/11/19", 32, "SY"],
    ["2015/11/20", 26, "SY"],
    ["2015/11/21", 35, "SY"],
    ["2015/11/22", 4, "SY"],
    ["2015/11/23", 32, "SY"],
    ["2015/11/24", 26, "SY"],
    ["2015/11/25", 22, "SY"],
    ["2015/11/26", 16, "SY"],
    ["2015/11/27", 22, "SY"],
    ["2015/11/28", 10, "SY"],
    ["2015/11/08", 10, "DD"],
    ["2015/11/09", 15, "DD"],
    ["2015/11/10", 35, "DD"],
    ["2015/11/11", 38, "DD"],
    ["2015/11/12", 22, "DD"],
    ["2015/11/13", 16, "DD"],
    ["2015/11/14", 7, "DD"],
    ["2015/11/15", 2, "DD"],
    ["2015/11/16", 17, "DD"],
    ["2015/11/17", 33, "DD"],
    ["2015/11/18", 4, "DD"],
    ["2015/11/19", 32, "DD"],
    ["2015/11/20", 26, "DD"],
    ["2015/11/21", 35, "DD"],
    ["2015/11/22", 40, "DD"],
    ["2015/11/23", 32, "DD"],
    ["2015/11/24", 26, "DD"],
    ["2015/11/25", 22, "DD"],
    ["2015/11/26", 16, "DD"],
    ["2015/11/27", 22, "DD"],
    ["2015/11/28", 10, "DD"],
]


(
    ThemeRiver(init_opts=opts.InitOpts(width="1600px", height="800px"))
    .add(
        series_name=x_data,
        data=y_data,
        singleaxis_opts=opts.SingleAxisOpts(
            pos_top="50", pos_bottom="50", type_="time"
        ),
    )
    .set_global_opts(
        tooltip_opts=opts.TooltipOpts(trigger="axis", axis_pointer_type="line")
    )
    .render("theme_river.html")
)
# Out:
# 'c:\\Users\\zhouy217\\OneDrive - Pfizer\\Documents\\datapipline_outline\\Data-Pipeline\\theme_river.html'

# %%
from pyecharts.components import Table
from pyecharts.options import ComponentTitleOpts

table = Table()

headers = ["City name", "Area", "Population", "Annual Rainfall"]
rows = [
    ["Brisbane", 5905, 1857594, 1146.4],
    ["Adelaide", 1295, 1158259, 600.5],
    ["Darwin", 112, 120900, 1714.7],
    ["Hobart", 1357, 205556, 619.5],
    ["Sydney", 2058, 4336374, 1214.8],
    ["Melbourne", 1566, 3806092, 646.9],
    ["Perth", 5386, 1554769, 869.4],
]
table.add(headers, rows)
table.set_global_opts(
    title_opts=ComponentTitleOpts(title="Table-基本示例", subtitle="我是副标题支持换行哦")
)
table.render("table_base.html")
# Out:
# 'c:\\Users\\zhouy217\\OneDrive - Pfizer\\Documents\\datapipline_outline\\Data-Pipeline\\table_base.html'

# %%
import wordtree
documents = ["hello world", "world is my oyster"]
g = wordtree.search_and_draw(corpus = documents, keyword = "world")
g.render() # creates a file world.dv.png
# Out:
# 100%|██████████| 2/2 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\ANACONDA3\envs\Simi_com\lib\site-packages\graphviz\backend\execute.py in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      80         else:
# ---> 81             proc = subprocess.run(cmd, **kwargs)
#      82     except OSError as e:
#
# C:\ANACONDA3\envs\Simi_com\lib\subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     487
# --> 488     with Popen(*popenargs, **kwargs) as process:
#     489         try:
#
# C:\ANACONDA3\envs\Simi_com\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     799                                 errread, errwrite,
# ...
